# %%
import pandas as pd
import numpy as nu
import matplotlib as mt

# %% [markdown]
# Import Files and get core information about the data set

# %%
Hrt =pd.read_csv(r"C:\Users\USER\Downloads\Dataset Heart Disease.csv")

# %%
view_info = Hrt.head()
print(view_info)
# Out:
#    Unnamed: 0  age  sex  chest pain type  resting bps  cholesterol  \
# 0           0   40    1                2          140        289.0
# 1           1   49    0                3          160        180.0
# 2           2   37    1                2          130        283.0
# 3           3   48    0                4          138        214.0
# 4           4   54    1                3          150        195.0
#
#    fasting blood sugar  resting ecg  max heart rate  exercise angina  oldpeak  \
# 0                    0            0             172                0      0.0
# 1                    0            0             156                0      1.0
# 2                    0            1              98                0      0.0
# 3                    0            0             108                1      1.5
# 4                    0            0             122                0      0.0
#
#    ST slope  target
# 0         1       0
# 1         2       1
# 2         1       0
# 3         2       1
# 4         1       0

# %%
view_data_details = Hrt.describe()
print(view_data_details)

# %%
print(Hrt['age'].value_counts())
# Out:
# age
# 54    63
# 58    55
# 57    48
# 55    43
# 52    43
# 59    40
# 56    39
# 51    38
# 48    36
# 62    36
# 60    33
# 41    32
# 53    31
# 44    30
# 46    29
# 63    28
# 43    28
# 50    28
# 61    27
# 64    27
# 45    25
# 49    25
# 42    24
# 65    24
# 67    22
# 47    20
# 39    19
# 66    17
# 40    14
# 35    14
# 37    13
# 69    12
# 38    12
# 68    11
# 70     9
# 71     8
# 34     8
# 74     6
# 36     5
# 32     4
# 29     4
# 75     3
# 76     3
# 77     3
# 72     3
# 33     2
# 31     2
# 30     1
# 28     1
# Name: count, dtype: int64

# %%
Density_Plot =Hrt['age'].plot(kind='box' , vert=True, figsize=(14,6))
