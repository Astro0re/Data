# %% [markdown]
# # Glass Classifications
# ### Attribute Information
# 1. Id number: 1 to 214 (removed from CSV file)
# 2. RI: refractive index
# 3. Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
# 4. Mg: Magnesium
# 5. Al: Aluminum
# 6. Si: Silicon
# 7. K: Potassium
# 8. Ca: Calcium
# 9. Ba: Barium
# 10. Fe: Iron
#
# ### Type of glass: (class attribute)
# 1. building_windows_float_processed
# 2. building_windows_non_float_processed
# 3. vehicle_windows_float_processed
# 4. vehicle_windows_non_float_processed (none in this database)
# 5. containers
# 6. tableware
# 7. headlamps

# %% [markdown]
# Why Glass: Has been implemented into various tools and mechanics used today, phones, houses, cars each serving its own purpose, this analysis is therefore useful when considering what type of glass to use for different applications and what are the needed elements, makeup it should posses

# %% [markdown]
# What should this display, what information should be conveyed:
# Glass with the highest refractive index(Privacy)
# Chemical properties present, general view in each type of glass
# What potentialy harmful chemicals are abundant in the types of glass which should be avoided(kept away from certain conditions)

# %% [markdown]
# Barium and alluminum are noted to be among the most harmful substances when exposed to in excess, are the rates of concentration in these glass classes been linked to health related issues.

# %% [markdown]
# ### Packages and Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat

# %%
glass=pd.read_csv(r"C:\Users\USER\Documents\Git_Hub Data\Data\Glass\glass.csv")
# Data Exploration
print(glass.shape)
print(glass.head())
print(glass.info())
print(glass.describe())
# Out:
# (214, 10)
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# ...

# %% [markdown]
# ### Group Data
# Seperate data

# %%
# 1
ty_1= glass[glass['Type'] == 1]
print(ty_1)
# 2
ty_2= glass[glass['Type'] == 2]
print(ty_2)
# 3
ty_3= glass[glass['Type'] == 3]
print(ty_3)
# 4
ty_4= glass[glass['Type'] == 4]
print(ty_4)
# 5
ty_5= glass[glass['Type'] == 5]
print(ty_5)
# 6
ty_6= glass[glass['Type'] == 6]
print(ty_6)
# 7
ty_7= glass[glass['Type'] == 7]
print(ty_7)
# Out:
#          RI     Na    Mg    Al     Si     K     Ca   Ba    Fe  Type
# 0   1.52101  13.64  4.49  1.10  71.78  0.06   8.75  0.0  0.00     1
# 1   1.51761  13.89  3.60  1.36  72.73  0.48   7.83  0.0  0.00     1
# 2   1.51618  13.53  3.55  1.54  72.99  0.39   7.78  0.0  0.00     1
# 3   1.51766  13.21  3.69  1.29  72.61  0.57   8.22  0.0  0.00     1
# 4   1.51742  13.27  3.62  1.24  73.08  0.55   8.07  0.0  0.00     1
# ..      ...    ...   ...   ...    ...   ...    ...  ...   ...   ...
# 65  1.52099  13.69  3.59  1.12  71.96  0.09   9.40  0.0  0.00     1
# 66  1.52152  13.05  3.65  0.87  72.22  0.19   9.85  0.0  0.17     1
# 67  1.52152  13.05  3.65  0.87  72.32  0.19   9.85  0.0  0.17     1
# 68  1.52152  13.12  3.58  0.90  72.20  0.23   9.82  0.0  0.16     1
# 69  1.52300  13.31  3.58  0.82  71.99  0.12  10.17  0.0  0.03     1
#
# [70 rows x 10 columns]
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# ...

# %% [markdown]
# ### Type Description

# %%
print(ty_1.describe())
print(ty_2.describe())
print(ty_3.describe())
print(ty_4.describe())
print(ty_5.describe())
print(ty_6.describe())
print(ty_7.describe())
# Out:
#               RI         Na         Mg         Al         Si          K  \
# count  70.000000  70.000000  70.000000  70.000000  70.000000  70.000000
# mean    1.518718  13.242286   3.552429   1.163857  72.619143   0.447429
# std     0.002268   0.499301   0.247043   0.273158   0.569484   0.214879
# min     1.512150  12.450000   2.710000   0.290000  71.350000   0.000000
# 25%     1.517540  12.825000   3.480000   1.112500  72.080000   0.200000
# 50%     1.517835  13.195000   3.565000   1.230000  72.815000   0.560000
# 75%     1.519560  13.525000   3.657500   1.327500  73.017500   0.590000
# max     1.526670  14.770000   4.490000   1.690000  73.700000   0.690000
#
#               Ca         Ba         Fe  Type
# count  70.000000  70.000000  70.000000  70.0
# mean    8.797286   0.012714   0.057000   1.0
# std     0.574807   0.083838   0.089075   0.0
# min     7.780000   0.000000   0.000000   1.0
# 25%     8.430000   0.000000   0.000000   1.0
# 50%     8.675000   0.000000   0.000000   1.0
# ...

# %% [markdown]
# ### Data Visualization

# %%
mat.boxplot([ty_1['RI'],ty_2['RI'],ty_3['RI'],ty_4['RI'],ty_5['RI'],ty_6['RI'],ty_7['RI']])
mat.title("Refractive index Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %%
mat.boxplot([ty_1['Na'],ty_2['Na'],ty_3['Na'],ty_4['Na'],ty_5['Na'],ty_6['Na'],ty_7['Na']])
mat.title("Sodium Content Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %%
mat.boxplot([ty_1['Mg'],ty_2['Mg'],ty_3['Mg'],ty_4['Mg'],ty_5['Mg'],ty_6['Mg'],ty_7['Mg']])
mat.title("Magnesium Content Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %%
mat.boxplot([ty_1['Al'],ty_2['Al'],ty_3['Al'],ty_4['Al'],ty_5['Al'],ty_6['Al'],ty_7['Al']])
mat.title("Aluminum Content Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %%
mat.boxplot([ty_1['Si'],ty_2['Si'],ty_3['Si'],ty_4['Si'],ty_5['Si'],ty_6['Si'],ty_7['Si']])
mat.title("Sillicon Content Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %%
mat.boxplot([ty_1['K'],ty_2['K'],ty_3['K'],ty_4['K'],ty_5['K'],ty_6['K'],ty_7['K']])
mat.title("Potassium content Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %%
mat.boxplot([ty_1['Ca'],ty_2['Ca'],ty_3['Ca'],ty_4['Ca'],ty_5['Ca'],ty_6['Ca'],ty_7['Ca']])
mat.title("Calcium content Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %%
mat.boxplot([ty_1['Ba'],ty_2['Ba'],ty_3['Ba'],ty_4['Ba'],ty_5['Ba'],ty_6['Ba'],ty_7['Ba']])
mat.title("Barium Content Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %% [markdown]
# Barium appears pervalent in the type 7 Glass(Head lanmps), apart from the occupational hazards involved in mining or other task requiring lights will still retaining free hands, could commmon trends of illnesses in minners be related to exposure to Barium in the case of broken/faulty equipment.

# %%
mat.boxplot([ty_1['Fe'],ty_2['Fe'],ty_3['Fe'],ty_4['Fe'],ty_5['Fe'],ty_6['Fe'],ty_7['Fe']])
mat.title("Iron Content Boxplot")
mat.xlabel("Glass Types")
mat.ylabel("Frequency")
mat.show()

# %%
mat.matshow(glass.corr())
mat.show()
